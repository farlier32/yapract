# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Привет, Никита :) Спасибо за исправления
#
# Критический ❌ комментарий один:
#
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value
#
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# можно посмотреть на подсказки в проекте стат. анализа и затем исправить расшифровку в этом проекте
#
#     Вероятность того или иного события, если p = 0,104...41, значит что разница между двумя значениями около 10%, не много. В то же время то что я сейчас сделал с выборкой nextgen, показывает что в 2014-2016 action и sport жанры сильно разняться

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Никита :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Анализ игровой индустрии для предсказания будущих трендов и увелиния продаж
#
# # Описание проекта
#
#     Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# # !!!
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# # ***
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# # Инструкция по выполнению проекта
# #  Откройте файл с данными и изучите общую информацию
# #  Подготовьте данные
#    - Замените названия столбцов (приведите к нижнему регистру);
#    - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
#    - Обработайте пропуски при необходимости:
#        - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#        - Опишите причины, которые могли привести к пропускам;
#        - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
#    - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# # Проведите исследовательский анализ данных
#    - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#    - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте      распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#    - Возьмите данные за соответствующий <b>актуальный период.</b> Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#    - Не учитывайте в работе данные за <b>предыдущие годы.</b>
#    - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#    - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#    - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#    - Соотнесите выводы с продажами игр на других платформах.
#    - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# # Составьте портрет пользователя каждого региона
#    - Определите для пользователя каждого региона (NA, EU, JP):
#    - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#    - Самые популярные жанры (топ-5). Поясните разницу.
#    - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
# # Проверьте гипотезы
#    - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#    - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#   Задайте самостоятельно пороговое значение alpha.
#
#   Поясните:
#
#    - Как вы сформулировали нулевую и альтернативную гипотезы;
#    - Какой критерий применили для проверки гипотез и почему.
# # Напишите общий вывод
# <b>Оформление:</b> Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту

# %% [markdown]
# ## Откроем файлы и импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns

pd.options.display.float_format = '{:.2f}'.format

# %%
games = pd.read_csv('/datasets/games.csv')
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games.describe()
# Out:
#        Year_of_Release  NA_sales  EU_sales  JP_sales  Other_sales  \
# count         16446.00  16715.00  16715.00  16715.00     16715.00
# mean           2006.48      0.26      0.15      0.08         0.05
# std               5.88      0.81      0.50      0.31         0.19
# min            1980.00      0.00      0.00      0.00         0.00
# 25%            2003.00      0.00      0.00      0.00         0.00
# 50%            2007.00      0.08      0.02      0.00         0.01
# 75%            2010.00      0.24      0.11      0.04         0.03
# max            2016.00     41.36     28.96     10.22        10.57
#
#        Critic_Score
# count       8137.00
# mean          68.97
# std           13.94
# min           13.00
# 25%           60.00
# 50%           71.00
# 75%           79.00
# max           98.00

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %% [markdown]
# ## Подготовка данных
#    - Замените названия столбцов (приведите к нижнему регистру);
#    - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
#    - Обработайте пропуски при необходимости:
#        - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#        - Опишите причины, которые могли привести к пропускам;
#        - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
#    - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
games.columns = games.columns.str.lower()
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii          2006.00        Sports     41.36
# 1         Super Mario Bros.      NES          1985.00      Platform     29.08
# 2            Mario Kart Wii      Wii          2008.00        Racing     15.68
# 3         Wii Sports Resort      Wii          2009.00        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB          1996.00  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45         76.00          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29         82.00        8.3      E
# 3     10.93      3.28         2.95         80.00          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
def date_time(df,column):
# заполнил пропуски, дату поставил '2222', потому что дата выхода неизвестна
    df[column] = df[column].fillna(2222)
    df[column] = df[column].astype('int')
    return df.head()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит посмотреть на платформы, к которым относятся пропуски, и с легкостью расстанешься с ними ...
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %%
date_time(games, 'year_of_release')
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45         76.00          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29         82.00        8.3      E
# 3     10.93      3.28         2.95         80.00          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
games['year_of_release'].sort_values(ascending=False).head()
# Out:
# 627     2222
# 7008    2222
# 8197    2222
# 8212    2222
# 3024    2222
# Name: year_of_release, dtype: int64

# %%
# check
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Часть функции не работает
#
#         def date_time(df,column):
#         # заполнил пропуски, дату поставил '2222', потому что дата выхода неизвестна
#             df[column] = df[column].fillna(2222)
#             df[column] = df[column].astype('int')
#             df[column] = df[column].astype('str')
#         # создаю временный столбец чтобы сделать полноценную дату ('2006' + '-01-01' = 2006-01-01).
#         # а потом сменить её тип на datetime
#             df['temp_date'] = '-01-01'
#             df[column] = df[column] + df['temp_date']
#             df[column] = pd.to_datetime(df[column], format='%Y-%m-%d').dt.year
#         # временный столбец удаляется, чтобы не путался
#             del df['temp_date']
#             return df.head()
#
# Проверка
#
#          2   year_of_release  16715 non-null  int64

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# що таке тбд!?

# %%
games[games['user_score'] == 'tbd']['user_score'].count()
# Out:
# 2424

# %%
games.loc[games['user_score'] == 'tbd','user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
games['user_score'] = games['user_score'].astype('float')

# %%
games.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %%
# заполняем пропуски
games['name'] = games['name'].fillna('no name')
games['rating'] = games['rating'].fillna('out of rating')
games['genre'] = games['genre'].fillna('no genre')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> отличное решение, пропуски приобрели название своей категории — «неизвестный рейтинг»

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

drop = games[(['total_sales'] == 0) & (games['genre'] == 'no genre')]
drop2 = games[(['total_sales'] == 0) & (games['rating'] == 'out of rating')]
print(drop,'\n\n', drop2)
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []
#
#  Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#      <br /> Объясни пожалуйста, зачем нам на проекте две практически полностью пустые записи
#
#
#         games['name'] = games['name'].fillna('No name')
#
#         games['genre'] = games['genre'].fillna('no genre')

# %% [markdown]
# # ^Я не могу их дропнуть, у позиций есть деньги^
# Да, я не могу их использовать для каких-то определённых задач, но при работе со всей выборкой они тоже важны.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
#      <br /> мы решаем главную задачу проекта - определить рекламную кампанию на 2017 год, игры из 1993 года ...
#
# на рабочих проектах стоит обращать внимание на такие факты пристальное внимание и не тратить ресурсы

# %% [markdown]
# # Понял-принял.
# # out of rating возможно является - Adults Only контентом, но менять не стал, там могли быть и другие игры, которые просто не имеют какого-либо рейтинга, может быть часть из них как раз с 1993 года до появления ESRB.

# %%
# проверим на дубликаты эта шарманку и для удобства всё сделаем масеньким!

games['name'] = games['name'].str.lower()
games['platform'] = games['platform'].str.lower()
games['genre'] = games['genre'].str.lower()

games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит привести к нижнему регистру и содержимое категориальных столбцов, до поиска возможных дубликатов

# %%
games.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating                0
# total_sales           0
# dtype: int64

# %%
no_name = games[games['name'] == 'no name']
no_name.head()
# Out:
#           name platform  year_of_release     genre  na_sales  eu_sales  \
# 659    no name      gen             1993  no genre      1.78      0.53
# 14244  no name      gen             1993  no genre      0.00      0.00
#
#        jp_sales  other_sales  critic_score  user_score         rating  \
# 659        0.00         0.08           NaN         NaN  out of rating
# 14244      0.03         0.00           NaN         NaN  out of rating
#
#        total_sales
# 659           2.39
# 14244         0.03

# %% [markdown]
# У игр без имени есть сборы - оставим их как есть

# %%
games['total_sales'] = games[['na_sales', 'eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score         rating  \
# 0     28.96      3.77         8.45         76.00        8.00              E
# 1      3.58      6.81         0.77           NaN         NaN  out of rating
# 2     12.76      3.79         3.29         82.00        8.30              E
# 3     10.93      3.28         2.95         80.00        8.00              E
# 4      8.89     10.22         1.00           NaN         NaN  out of rating
#
#    total_sales
# 0        82.54
# ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
score_0 = games[games['user_score'] == 0]
score_0.head()
# Out:
#                                     name platform  year_of_release      genre  \
# 2835  my little pony: pinkie pie's party       ds             2008  adventure
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 2835      0.66      0.00      0.00         0.06           NaN        0.00
#
#      rating  total_sales
# 2835      E         0.72

# %% [markdown]
# Заполнять оценки я не стал, потому что есть реальные оценки "0", оставлю как есть, просто их нет в рейтинге.

# %% [markdown]
# ## Проведите исследовательский анализ данных
#    - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#    - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте      распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#    - Возьмите данные за соответствующий <b>актуальный период.</b> Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#    - Не учитывайте в работе данные за <b>предыдущие годы.</b>
#    - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#    - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#    - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#    - Соотнесите выводы с продажами игр на других платформах.
#    - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# ### Cоздам функцию для гистограмм

# %%
def games_plot(df, column, func, y='name', xl=None,yl=None):
    temp_df = df[df['year_of_release'] != 2222]
    temp_df2 = temp_df.groupby(column)[y]
    if func == 'count':
        calculate_df = temp_df2.count()
        plot = calculate_df.plot(kind='bar',
                                 y=y, figsize=(15,5),
                                 ec='black', color='pink',
                                xlabel=xl, ylabel=yl)
        
    elif func == 'sum':
        calculate_df = temp_df2.sum().sort_values()
        plot = calculate_df.plot(kind='barh',
                                 y=y,
                                 figsize=(15,10),
                                 ec='black', color='pink',
                                xlabel=xl, ylabel=yl)

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы.

# %%
games_plot(games, 'year_of_release', 'count', xl='Года', yl='Кол-во игр')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, наглядный
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html).

# %% [markdown]
# Судя по графику игровая индустрия начали развиваться в 1980-х, что правда, она сама появилась несколькими годами ранее. После 90-х начинается скачок и подъём индустрии, что-то произошло к девятому году... Начала быстро развиваться мобильная индустрия, может инди студий стало меньше, инвестиции могли просесть, вот и количество релизов упало.
#
# Тут красивее видно это, да ещё и в денежном эквиваленте -

# %%
games[games['year_of_release'] != 2222]\
                        .groupby('year_of_release')\
                        .agg({'total_sales':'sum'})\
                        .plot(xlabel='Года', ylabel = 'Сумма продаж(млн. $)')\
                        .legend()

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам

# %%
games_plot(games, 'platform', 'sum', 'total_sales', xl='Платформы', yl='Сумма продаж(млн.$)')

# %% [markdown]
# Топ 5: ps2, x360, ps3, wii, ds.
#
# уверен что топ после 2011 будет из тех же консолей нового поколения) ps4, wiiu, xone, 3ds. 3ds в принципе линейку восьмого поколения открыла.

# %% [markdown]
# ### Актуальные года для исследования
#
# - Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# - Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# Я возьму за актуальные года момент смены поколений консолей, а именно с появления <a href="https://ru.wikipedia.org/wiki/%D0%92%D0%BE%D1%81%D1%8C%D0%BC%D0%BE%D0%B5_%D0%BF%D0%BE%D0%BA%D0%BE%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B8%D0%B3%D1%80%D0%BE%D0%B2%D1%8B%D1%85_%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC"> восьмого поколения игровых систем </a> и конца <a href="https://ru.wikipedia.org/wiki/%D0%A1%D0%B5%D0%B4%D1%8C%D0%BC%D0%BE%D0%B5_%D0%BF%D0%BE%D0%BA%D0%BE%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B8%D0%B3%D1%80%D0%BE%D0%B2%D1%8B%D1%85_%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC"> седьмого </a>, в 2011 году.
#
# ///    Их список возьму <a href="https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%B8%D0%B3%D1%80%D0%BE%D0%B2%D1%8B%D1%85_%D0%BA%D0%BE%D0%BD%D1%81%D0%BE%D0%BB%D0%B5%D0%B9">отсюда</a> до 16-го года. ///

# %%
nextgen = games[games['year_of_release'] >= 2014].reset_index(drop=True)
nextgen = nextgen[nextgen['year_of_release'] != 2222]

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит

# %% [markdown]
# # ^взял период поменьше, до всплеска игр в 2015

# %%
nextgen.head()
# Out:
#                                         name platform  year_of_release  \
# 0                  call of duty: black ops 3      ps4             2015
# 1                         grand theft auto v      ps4             2014
# 2  pokemon omega ruby/pokemon alpha sapphire      3ds             2014
# 3                                    fifa 16      ps4             2015
# 4               star wars battlefront (2015)      ps4             2015
#
#           genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0       shooter      6.03      5.86      0.36         2.38           NaN
# 1        action      3.96      6.31      0.38         1.97         97.00
# 2  role-playing      4.35      3.49      3.10         0.74           NaN
# 3        sports      1.12      6.12      0.06         1.28         82.00
# 4       shooter      2.99      3.49      0.22         1.28           NaN
#
#    user_score         rating  total_sales
# 0         NaN  out of rating        14.63
# ...

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают?

# %%
games_plot(nextgen, 'platform', 'sum', 'total_sales')

# %% [markdown]
# Что я и предпологал)
#
# Очень заметно как по сравнению со всем продажами за всё время, продажи на второй плейстейшн просто упали в ноль на момент выгрузки этих данных. А консоли тогда нового поколения на момент этого тикета всё ещё приносили деньги. Всегда в игровой индустрии маркетам важно смотреть что будет актуально.
#
# Самые лучшие по продажам:
# 1. ps3
# 2. x360
# 3. ps4
# 4. 3ds
# 5. xone

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %%
nextgen.describe()
# Out:
#        year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# count          1689.00   1689.00   1689.00   1689.00      1689.00
# mean           2014.95      0.17      0.16      0.06         0.05
# std               0.80      0.45      0.47      0.21         0.14
# min            2014.00      0.00      0.00      0.00         0.00
# 25%            2014.00      0.00      0.00      0.00         0.00
# 50%            2015.00      0.02      0.02      0.01         0.01
# 75%            2016.00      0.12      0.12      0.04         0.04
# max            2016.00      6.03      6.31      3.18         2.38
#
#        critic_score  user_score  total_sales
# count        718.00      888.00      1689.00
# mean          72.31        6.62         0.43
# std           12.21        1.59         1.06
# min           19.00        0.20         0.01
# 25%           66.00        5.80         0.03
# 50%           74.00        7.00         0.10
# 75%           81.00        7.80         0.35
# ...

# %%
nextgen.boxplot('total_sales', figsize=(10,10))
plt.title('Продажи новых платформ')
# Out:
# Text(0.5, 1.0, 'Продажи новых платформ')

# %%
nextgen.boxplot('total_sales', figsize=(10,10)).set_ylim(0,2.5)
plt.title('Продажи новых платформ')
# Out:
# Text(0.5, 1.0, 'Продажи новых платформ')

# %% [markdown]
# Писят на писят как сказал бы 50 центов... Либо студия заработает, либо нет.

# %%
top = ['ps3', 'x360', 'ps4', '3ds', 'xone']
def boxplot(df, query_condition=None, ylim=None):
    df_query = df.query(query_condition)
    by_column = query_condition.split()[0]
    return df_query.boxplot(column='total_sales', by=by_column, fontsize=25, figsize=(25,10)).set_ylim(ylim)

# %%
boxplot(nextgen, query_condition='platform in @top')
# Out:
# (-0.721, 15.360999999999999)

# %%
boxplot(nextgen, query_condition='platform in @top', ylim=(0,3))
# Out:
# (0.0, 3.0)

# %% [markdown]
# Медиана по топовым платформам варьируется от 0,2 до 0,25 млн долларов прибыли за игру.
# Верхняя граница предела, за которыми уже определяются аномалии, у двух платформ - PS3 и X360 - на уровне 1,7 млн долларов.
# У остальных - от 1 до 1,5 миллионов долларов.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Диаграмму размаха для оценки
#
#         Разброс продаж в разрезе платформ
#
# стоит нарисовать по сырым данным из выборки nextgen, так мы сможем сравнить все актуальные платформы

# %% [markdown]
# # Вроде поправил

# %%
# код от ревьюера
import seaborn as sns

df_af =  games[(games['year_of_release'] >= 2015) & (games['year_of_release'] <= 2016)].reset_index(drop=True)

plt.figure(figsize=(13, 6))
(sns.boxplot(data = df_af, y = 'total_sales', x='platform')
    .set(title = 'Продажи по перспективным платформам за 2014-2016 гг', xlabel = 'Платформы', 
         ylabel = 'Общие продажи')
)

plt.show()

df_af =  games[(games['year_of_release'] >= 2015) & (games['year_of_release'] <= 2016)].reset_index(drop=True)

plt.figure(figsize=(13, 6))
(sns.boxplot(data = df_af, y = 'total_sales', x='platform')
    .set(title = 'Продажи по перспективным платформам за 2014-2016 гг', xlabel = 'Платформы', 
         ylabel = 'Общие продажи', ylim=(0,2))
)

plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Стоит добавить второй вид диаграммы размаха, со всеми выбросами, это наши рекордсмены по выручке :)

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.

# %%
games_ps3 = games[(games['platform'] == 'ps3') & (games['critic_score'] > 0)].copy()
games_ps3.plot(kind='scatter', x='critic_score', y='total_sales', ec='black', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='total_sales'>

# %% [markdown]
# Количество продаж растёт с оценкой игры, логично!

# %%
games_ps3 = games[(games['platform'] == 'ps3') & (games['critic_score'] > 0)].copy()
games_ps3.plot(kind='scatter', x='user_score', y='total_sales', ec='black', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='total_sales'>

# %% [markdown]
# Всё то же самое, но здесь заметно больше выбросов.

# %%
plt.figure(figsize=(9,9))
sns.heatmap(games_ps3.corr(), annot=True, cmap="Reds", fmt='.2f', annot_kws={'size':16})
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %%
games_ps3_filtered = games_ps3[['total_sales' ,'critic_score', 'user_score']]
plt.figure(figsize=(1,3))
sns.heatmap(games_ps3_filtered.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), cmap="Reds", 
            annot=True, annot_kws={'size':15})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Чаще всего прибыли больше у тех игр, у которых высокие оценки критиков, по данным оценок пользователей почти не прослеживается.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#     Сильнее всего на конечную стоимость влияет оценка критиков. Оценка пользователей почти не влияет.
#
# Достаточно много игр с высокой оценкой критиков и слабой выручкой
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %%
top = ['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps', 'ps4', 'xone']

rows = len(top) // 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(15,8.5))
count = 0
for r in range(rows):
    for c in range(cols):
        curr_platform = top[count]
        df_prep = games[(games['platform'] == curr_platform) & (games['user_score'] > 0)].copy()
        
        df_filtered = df_prep[['total_sales' ,'critic_score', 'user_score']]
        sns.set(font_scale=1.0)
        ax = sns.heatmap(df_filtered.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), 
                         cmap="Reds", annot=True, annot_kws={'size':15}, ax=axes[r,c])
        ax.set_title(curr_platform, fontsize=20)
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        plt.tight_layout(pad=3)
        count += 1

# %% [markdown]
# Данные по корреляции между выручкой и оценкой по платформам PS2, X360, PS3, PS и XOne более или менее совпадает с общими данными по датафрейму.
# Выделяются Wii и DS, по которым зависимость не такая большая.
# Кстати, есть платформы, где оценка критиков, согласно данных, сильнее "определяет" конечную выручку продукта, чем оценка пользователей. Это платформы DS, PS4 и Xone. В случае с DS полагаю, что дело в том, что приставка азиатская, большую популярность она имеет там, соответственно, далеко не большая часть игроков принимает участие в оценке игр на эту платформу. Про PS4 и Xone - платформы довольно новые, вполне вероятно, что пользователи пока не "освоились", поэтому большого количества отзывов, особенно качественных от них нет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Анализ наличия зависимости по нескольким платформам придает вес твоему исследованию, молодец

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам.

# %%
games.boxplot(column='total_sales', by='genre', fontsize=25, figsize=(40,15)).set_ylim()
# Out:
# (-4.127, 86.66699999999999)

# %%
games.boxplot(column='total_sales', by='genre', fontsize=25, figsize=(40,15)).set_ylim(0,2.5)
# Out:
# (0.0, 2.5)

# %% [markdown]
# Самые стабильные жанры - Экшн, РП, спорт. "разное(misc)" не знаю можно ли считать стабильным так как это смесь жанров, а не что-то отдельное. После них идут приключения, шутеры, платформемы, файтинги и стратегии с пазлами.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать в двух масштабах с выбросами и без (чтобы было видно 75 квартиль)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# наш ноу жанра играет отвлекающую роль, и мы не видим, что шутеры выходят на первое место ...

# %% [markdown]
# ## Составьте портрет пользователя каждого региона

# %% [markdown]
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.

# %%
def regions_plot(df, groupby, region_sales, ax):
    pivot = df.groupby(groupby).agg({region_sales: 'sum'}).sort_values(by=region_sales, ascending=False)[:5]
    title_dict = {'na_sales': 'North America Sales', 'eu_sales': 'Europe Sales', 'jp_sales': 'Japan Sales'}
    color_dict = {'na_sales': 'blue', 'eu_sales': 'gray', 'jp_sales': 'forestgreen'}
    plot = pivot.plot(kind='bar', ec='black', title=title_dict[region_sales], ax=axes[ax], 
                   fontsize=18, color=color_dict[region_sales], rot=20)
    plot.legend(prop={'size':17})
    plot.set_xlabel('')
    plot.title.set_size(20)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

regions_plot(games, 'platform', 'na_sales', 0)
regions_plot(games, 'platform', 'eu_sales', 1)
regions_plot(games, 'platform', 'jp_sales', 2)

# %% [markdown]
# В Северной Америке имеют(имели) бешеную популярность приставки прошлого поколения X360 и PS2. Немного отстает Wii. Топ-4 и топ-5 - PS3 и DS соответственно.
#
# В Европе одинаково (были) популярны PS2 и PS3. За ними X360, Wii и PS.
#
# В Японии, как обычно, всё наоборот. Лидер - DS. За ними американские PS и PS2. Далее чисто японские SNES и 3DS.

# %% [markdown]
# ### Самые популярные жанры (топ-5). Поясните разницу.

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

regions_plot(games, 'genre', 'na_sales', 0)
regions_plot(games, 'genre', 'eu_sales', 1)
regions_plot(games, 'genre', 'jp_sales', 2)

# %% [markdown]
# Вкусы в Северной Америке и Европе схожи: и там, и там живут фанаты экшнов, спортивных игр и шутеров. В Северной Америке больше играют в платформеры, в Европе же чаще выбирают гонки.
#
#
# В Японии вкус совершенно иной - на первом месте ролевые игры, причем с большим отрывом. Далее экшны и спортивные игры.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов отрисованы, молодец, сильное влияние на портрет оказывает период выборки games, можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
#
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/?ysclid=l4q3l4q0p8940570437
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html?highlight=append#pandas.DataFrame.append

# %% [markdown]
# # ^ Не совсем понял что такое двухуровневый заголовок из того что дали, только вот это похоже на что-то "двухуровневое".![image.png](attachment:image.png)

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

regions_plot(games, 'rating', 'na_sales', 0)
regions_plot(games, 'rating', 'eu_sales', 1)
regions_plot(games, 'rating', 'jp_sales', 2)

# %% [markdown]
# В Северной Америке и в Европе картина практически одинаковая. Большая часть выручки получено с игр с рейтингом "E", и "Out of rating", поровну - с рейтингом "T" и "M".
#
# В Японии опять не так. Первое место "out of rating", намного меньше выручка с "E", и третьим идёт с небольшой разнизой - "T".
#
# Out Of Rating - как я предпологаю это AO - Adults Only content, скорее всего так и есть.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга
#
#         games_r = games[games['rating'] != 'out of rating']

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит поправить вывод

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.query('year_of_release >= 2015').dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, region, name, axes):
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, labels = sales.platform,
               
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    plt.tight_layout()

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

graph(data_games, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, 'eu_sales', 'Европе', axes[1])
graph(data_games, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />2015 год взят для примера, чтобы показать усиление позиций современных платформ

# %% [markdown]
# ## Проверка гипотез
#
#     Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
#     Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
#
#     Поясните:
#
#         Как вы сформулировали нулевую и альтернативную гипотезы;
#         Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# ### Гипотеза № 1:
#
#     Н0: средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
#     Н1: средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> гипотезы сформулированы верно

# %%
xone = nextgen[(nextgen['platform'] == 'xone') & (nextgen['user_score'] > 0)]['user_score']
pc = nextgen[(nextgen['platform'] == 'pc') & (nextgen['user_score'] > 0)]['user_score']

result = st.ttest_ind(xone, pc)
alpha = 0.05

print ('p =', result.pvalue)
if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p = 0.10450507919348415
# Не отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Вопрос дублирую, подсказки оставил
#
#         Что означает на языке статистики p = 0.10450507919348415

# %% [markdown]
# # ^ Вероятность того или иного события: Если p = 0,104...41, значит что вероятность получить такую разницу в наших выборках случайно примерно 10%.
# # Нулевая гипотеза не отвергается, вероятность большая.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит выравнивать периоды использования платформ при исправлении кода, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# #  ^Выровнял

# %% [markdown]
# Cредние пользовательские рейтинги платформ Xbox One и PC одинаковы между собой.

# %%
print('Средняя оценка пользователей игр для платформы Xbox One  - {:.2f}'.format(xone.mean()))
print('Средняя оценка пользователей игр для платформы PC - {:.2f}'.format(pc.mean()))
# Out:
# Средняя оценка пользователей игр для платформы Xbox One  - 6.59
# Средняя оценка пользователей игр для платформы PC - 6.30

# %% [markdown]
# Если смотреть на рейтинги с 2014 по 2016, то они у двух платформ почти не имеют различий.

# %% [markdown]
# ### Гипотеза № 2:
# Н0: средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# Н1: средние пользовательские рейтинги жанров Action и Sports отличаются между собой.

# %%
action = nextgen[(nextgen['genre'] == 'action') & (nextgen['user_score'] > 0)]['user_score']
sports = nextgen[(nextgen['genre'] == 'sports') & (nextgen['user_score'] > 0)]['user_score']
result = st.ttest_ind(action, sports)

alpha = .05

print ('p =', result.pvalue)
if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p = 2.8711147985105864e-19
# Отвергаем нулевую гипотезу

# %%
# Out:
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p = 0.10406951359049141

# %% [markdown]
# # x2^ Вероятность того или иного события: Если p = 0,104...41, значит что вероятность получить такую разницу в наших выборках случайно примерно 10%.
# # Нулевая гипотеза не отвергается, вероятность большая.

# %% [markdown]
# Средние пользовательские рейтинги не сильно разняться от жанров.

# %%
print('Средняя оценка пользователей игр для жанра Action - {:.2f}'.format(action.mean()))
print('Средняя оценка пользователей игр для жанра Sport - {:.2f}'.format(sports.mean()))
# Out:
# Средняя оценка пользователей игр для жанра Action - 6.76
# Средняя оценка пользователей игр для жанра Sport - 5.23

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> можно подправить некоторые моменты
#
#         Остается верным утверждение, что средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# По проведенному анализу: самое сильное влияние на итоговую выручку оказывают, в большинстве случаев, оценки критиков. Оценки пользователей таким "влиянием" на выручку похвастаться не могут. Необходимо копать в эту сторону.
#
# В целом про положение дел в игровой индустрии: рынок "немобильных" игр постепенно погибает. Все сейчас в погоне за графикой, новыми технологями, в связи с этим средний бюджет на разработку одной игры за последние годы заметно вырос.
#
# В итоге, гиганты игровой индустрии гоняются за технологиями, а более мелкие компании, не имеющие таких бюджетов, вынуждены отступать.
# Всё это привело к тому, что рынок уже который год падает. И, скорее всего, будет падать.
#
# Прибыль разнится от жанров, чаще всего самые большие продажи у шутеров, экшенов и спортивных игр. Соревновательные игры - вот что даёт больше всего денег в европейских и американских регионах. В японии больше приносят такие жанры как role play, и экшены.
#
# Так же прибыль разных платформ тоже разнится от регионов, в европейском регионе больше всего идёт в PS, Xbox. В Японии большие продажи как с PS, так и с местных платформ как Nintendo DS.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Практически идеальный вывод, есть сравнения рынков, инсайты, самое главное итоговая рекомендация бизнесу, молодец

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Оформление вывода: стоит кратко напомнить цель исследования, как мы его провели, какие параметры рассматривали, какие редкие и выбивающиеся значения убрали, какие особенности и инсайты в данных нашли (упоминаем только основные 3-5,  с приведением найденных числовых значений), выделяем сильные корреляционные связи на парных признаках, если они есть
#
# Не забываем формировать перечень рекомендаций для выбора конкретной платформы, жанра, рейтинга  для рекламной кампании 2017 года для каждого региона
#
#
#
# Минимальный объем для вывода это 3-4 абзаца, оптимальный 10-12, в т.ч. можно включать все промежуточные выводы

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить название
#
#  + сократить категории в рейтингах — на твое усмотрение
#  + самое важное — переопределить актуальный период
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#
#  + оценить прибыльность жанров на диаграмме размаха
#  + построить графики в ТОП-5 и пересмотреть раздел рейтингов
#  + в разделе проверки гипотез подправить выборки и вывод плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#  + дополнить итоговый вывод
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
